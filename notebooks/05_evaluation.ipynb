# %% [markdown]
# # Evaluation — Confusion Matrix & Per-Class Metrics (v3)
#
# Evaluating the 91.91% v3 model on the full GTSRB test set (12,630 images) using a confusion matrix and per-class precision/recall/F1.

# %% [markdown]
# ## Confusion Matrix
#
# ![Confusion Matrix](../confusion_matrix.png)
#
# ## Worst 10 Classes by Recall
#
# | Class | Precision | Recall | F1 | Support |
# |---|---|---|---|---|
# | 0 | 0.689 | 0.517 | 0.590 | 60 |
# | 21 | 0.962 | 0.556 | 0.704 | 90 |
# | 19 | 0.854 | 0.583 | 0.693 | 60 |
# | 39 | 1.000 | 0.678 | 0.808 | 90 |
# | 23 | 0.941 | 0.740 | 0.828 | 150 |
# | 30 | 0.683 | 0.747 | 0.713 | 150 |
# | 22 | 0.929 | 0.767 | 0.840 | 120 |
# | 8 | 0.913 | 0.791 | 0.848 | 450 |
# | 5 | 0.788 | 0.832 | 0.809 | 630 |
# | 28 | 0.857 | 0.840 | 0.848 | 150 |
#
# **Overall accuracy:** 0.9191
# **Macro avg F1:** 0.8977
# **Weighted avg F1:** 0.9185

# %% [markdown]
# ## Interpretation
# *the macro vs weighted F1 gap (2 point gap) implicates the imbalance in the number of images we have per class. classes like class 21 and 39 shows a near perfect precision and  a relatively low recall , however in other cases like classes 30 and 5 have the opposite pattern which indicates that they are acting as a 'default guess".*

# %% [markdown]
# ## Analysis on top confusions for the weakest classes
# *Class 0 (correctly predicted 31 times):
#   -> predicted as class 1: 24 times
#   -> predicted as class 4: 3 times
#   -> predicted as class 2: 2 times
#
# Class 21 (correctly predicted 50 times):
#   -> predicted as class 11: 19 times
#   -> predicted as class 31: 14 times
#   -> predicted as class 19: 3 times
#
# Class 19 (correctly predicted 35 times):
#   -> predicted as class 31: 21 times
#   -> predicted as class 25: 2 times
#   -> predicted as class 26: 1 times
#
# Class 39 (correctly predicted 61 times):
#   -> predicted as class 33: 25 times
#   -> predicted as class 38: 2 times
#   -> predicted as class 35: 1 times
#
# Class 23 (correctly predicted 111 times):
#   -> predicted as class 31: 16 times
#   -> predicted as class 30: 13 times
#   -> predicted as class 20: 8 times*
#
# # Cluster 1-Speed limit digit confusion
# *classes like 0 and 1 have almost identical signs (20km/h and 30km/h) they only differ in one digit which is a geniunely harder recognition task then shapes and colors.*
#
# # Cluster 2-Triangular warning sign confusion
# *signs with triangular shapes like 19,31,21,11,31 they are almost identical in colors and shapes and they only differ in a small pictogram*
#
# *this is exactly the sort of limitation a low resolution 32x32 input struggles with*
